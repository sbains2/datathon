# %%
import pandas as pd

# %%
df = pd.read_csv('us_mexico_border.csv')
df
# Out:
#              Port Name       State  Port Code            Border      Date  \
# 0                 Roma       Texas       2310  US-Mexico Border  Dec 2023
# 1              Del Rio       Texas       2302  US-Mexico Border  Dec 2023
# 2                 Roma       Texas       2310  US-Mexico Border  Nov 2023
# 3              Douglas     Arizona       2601  US-Mexico Border  Oct 2023
# 4               Laredo       Texas       2304  US-Mexico Border  Aug 2023
# ...                ...         ...        ...               ...       ...
# 92080  Rio Grande City       Texas       2307  US-Mexico Border  Mar 2024
# 92081          El Paso       Texas       2402  US-Mexico Border  Mar 2024
# 92082     Santa Teresa  New Mexico       2408  US-Mexico Border  Mar 2024
# 92083        Lukeville     Arizona       2602  US-Mexico Border  Mar 2024
# 92084    Calexico East  California       2507  US-Mexico Border  Mar 2024
#
#                            Measure  Value  Latitude  Longitude  \
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%b %Y')
df['Month'] = df['Date'].dt.month
df['Year'] = df['Date'].dt.year

# Drop the original 'Date' column if no longer needed
df = df.drop(columns=['Date'])
descriptive_stats = df.groupby(['Port Name', 'Year']).describe()
descriptive_stats['Value']
# Out:
#                 count           mean            std      min       25%  \
# Port Name Year
# Andrade   1996  144.0   24665.138889   51965.628986      0.0      0.00
#           1997  144.0   24815.618056   52369.968817      0.0      0.00
#           1998  144.0   26196.361111   54733.126866      0.0      0.00
#           1999  144.0   28312.611111   59002.292453      0.0      0.00
#           2000  144.0   29057.652778   61421.454398      0.0      0.00
# ...               ...            ...            ...      ...       ...
# Ysleta    2020   55.0   95212.472727   89879.536630  10622.0  29446.00
#           2021   76.0  117211.236842  116056.007083      1.0  33951.50
#           2022   72.0  155684.222222  156598.106002  14828.0  35347.00
#           2023   71.0  174324.084507  178436.372916  11285.0  39108.50
#           2024   18.0  179046.277778  179205.771026  18848.0  54339.25
#
#                     50%        75%       max
# Port Name Year
# ...

# %%
total_avgs = df.groupby('Year').describe()
total_avgs['Value']
# Out:
#        count           mean            std  min      25%      50%        75%  \
# Year
# 1996  3600.0   76875.402222  294052.170832  0.0     0.00    303.0   10905.75
# 1997  3600.0   96850.413333  349508.367933  0.0     0.00    432.5   19252.50
# 1998  3600.0  101749.059444  359122.408271  0.0     0.00    460.0   20578.50
# 1999  3600.0  108877.610000  380420.932325  0.0     0.00    573.0   23409.00
# 2000  3600.0  108953.296944  376851.091397  0.0     0.00    594.0   24274.25
# 2001  3600.0  100830.975278  341751.781678  0.0     0.00    581.5   24419.75
# 2002  3600.0   98019.478611  308107.215818  0.0     0.00    558.0   27398.00
# 2003  3600.0   95459.510833  311763.581953  0.0     0.00    532.0   25173.00
# 2004  3600.0   95423.521111  302287.284453  0.0     0.00    543.0   25583.00
# 2005  3600.0   93608.490833  297732.527525  0.0     0.00    614.5   25254.50
# 2006  3600.0   90996.673889  289532.817758  0.0     0.00    700.5   25254.75
# ...

# %%
state_avgs = df.groupby(['State', 'Year']).describe()
state_avgs['Value']
# Out:
#                count           mean            std   min      25%      50%  \
# State   Year
# Arizona 1996   864.0   44026.619213  130715.221156   0.0     0.00    151.5
#         1997   864.0   46886.991898  137258.996058   0.0     0.00    198.5
#         1998   864.0   47964.496528  141821.160601   0.0     0.00    243.0
#         1999   864.0   51284.406250  149501.099486   0.0     0.00    300.0
#         2000   864.0   53767.810185  158829.877579   0.0     0.00    299.5
# ...              ...            ...            ...   ...      ...      ...
# Texas   2020  1137.0   67418.817062  136413.357933   1.0  1730.00  14006.0
#         2021  1153.0   78336.170859  146171.468470   1.0  2295.00  14818.0
#         2022  1132.0  105361.891343  201580.291200   8.0  2699.25  15808.0
#         2023  1160.0  110523.365517  208213.191168   1.0  2440.50  16943.0
#         2024   292.0  112794.667808  202438.129360  46.0  2491.50  18463.5
#
#                     75%        max
# State   Year
# ...
